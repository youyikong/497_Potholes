# %% [markdown]
# After I loaded in the data I only did some basic cleaning, enough to start processing the data.
#
# * Changed the column names to a consistent capitalization.
# * Changed Creation Date and Completion Date to datetime fields
# * Deleted the columns containing "Dup", so we would only have unique requests
# * Dropped the (2) rows in the dataframe which were almost completely NA, including Street Address
# * Reset the index

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
url = 'https://data.cityofchicago.org/api/views/7as2-ds3y/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(url, sep=',', dtype={"Completion Date": object})
df.columns = ['Creation Date', 'Status', 'Completion Date', 'Service Request Number', 'Type of Service Request', 'Current Activity', 'Most Recent Action', 'Number of Potholes Filled on Block', 'Street Address', 'Zip', 'X Coordinate', 'Y Coordinate', 'Ward', 'Police District', 'Community Area', 'SSA', 'Latitude', 'Longitude', 'Location']
df['Creation Date'] =  pd.to_datetime(df['Creation Date'])
df['Completion Date'] =  pd.to_datetime(df['Completion Date'])
df = df[~df['Status'].str.contains("Dup")]
df = df.dropna(subset=['Street Address'])
df = df.reset_index(drop=True)
df.head().T
# Out:
# /home/anna/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                           0  \
# Creation Date                                           2011-01-01 00:00:00
# Status                                                            Completed
# Completion Date                                         2011-01-03 00:00:00
# Service Request Number                                          11-00002021
# Type of Service Request                                  Pot Hole in Street
# Current Activity                                              Dispatch Crew
# Most Recent Action                                          Pothole Patched
# Number of Potholes Filled on Block                                        5
# Street Address                                               1642 W 99TH ST
# Zip                                                                   60643
# X Coordinate                                                    1.16695e+06
# Y Coordinate                                                    1.83906e+06
# Ward                                                                     19
# Police District                                                          22
# Community Area                                                           72
# SSA                                                                     NaN
# Latitude                                                             41.714
# Longitude                                                          -87.6651
# Location                            (41.71403466751051, -87.66509581640723)
#
#                                                                           1  \
# Creation Date                                           2011-01-01 00:00:00
# Status                                                            Completed
# Completion Date                                         2011-01-03 00:00:00
# Service Request Number                                          11-00002273
# Type of Service Request                                  Pot Hole in Street
# Current Activity                                              Dispatch Crew
# Most Recent Action                                          Pothole Patched
# Number of Potholes Filled on Block                                        7
# Street Address                                            3500 S PULASKI RD
# Zip                                                                   60623
# X Coordinate                                                    1.15026e+06
# Y Coordinate                                                    1.88134e+06
# Ward                                                                     22
# Police District                                                          10
# Community Area                                                           30
# SSA                                                                     NaN
# Latitude                                                            41.8302
# Longitude                                                          -87.7244
# Location                            (41.830223541014355, -87.7243519544564)
#
#                                                                           2  \
# Creation Date                                           2011-01-01 00:00:00
# Status                                                            Completed
# Completion Date                                         2011-01-03 00:00:00
# Service Request Number                                          11-00002650
# Type of Service Request                                  Pot Hole in Street
# Current Activity                                              Dispatch Crew
# Most Recent Action                                          Pothole Patched
# Number of Potholes Filled on Block                                        5
# Street Address                           7851 S DR MARTIN LUTHER KING JR DR
# Zip                                                                   60619
# X Coordinate                                                    1.18027e+06
# Y Coordinate                                                    1.85304e+06
# Ward                                                                      6
# Police District                                                           6
# Community Area                                                           69
# SSA                                                                      51
# Latitude                                                            41.7514
# Longitude                                                          -87.6148
# Location                            (41.75143385051753, -87.61481960290558)
#
#                                                                           3  \
# Creation Date                                           2011-01-01 00:00:00
# Status                                                            Completed
# Completion Date                                         2011-01-03 00:00:00
# Service Request Number                                          11-00002654
# Type of Service Request                                  Pot Hole in Street
# Current Activity                                              Dispatch Crew
# Most Recent Action                                          Pothole Patched
# Number of Potholes Filled on Block                                        3
# Street Address                                                 15 E 79TH ST
# Zip                                                                   60619
# X Coordinate                                                    1.17781e+06
# Y Coordinate                                                    1.85264e+06
# Ward                                                                      6
# Police District                                                           6
# Community Area                                                           44
# SSA                                                                     NaN
# Latitude                                                            41.7509
# Longitude                                                          -87.6239
# Location                            (41.75086472111055, -87.62388985583482)
#
#                                                                           4
# Creation Date                                           2011-01-01 00:00:00
# Status                                                            Completed
# Completion Date                                         2011-01-03 00:00:00
# Service Request Number                                          11-00002656
# Type of Service Request                                  Pot Hole in Street
# Current Activity                                              Dispatch Crew
# Most Recent Action                                          Pothole Patched
# Number of Potholes Filled on Block                                        4
# Street Address                                                359 E 79TH ST
# Zip                                                                   60619
# X Coordinate                                                    1.17997e+06
# Y Coordinate                                                    1.85271e+06
# Ward                                                                      6
# Police District                                                           6
# Community Area                                                           44
# SSA                                                                      51
# Latitude                                                             41.751
# Longitude                                                          -87.6158
# Location                            (41.75099208108744, -87.61582439398472)

# %%
phc = df[df['Creation Date'].dt.year==2017]
phc = phc.dropna(subset=['Ward'])
phc = phc[phc['Ward']!=0]
phc = phc.groupby("Ward")["Number of Potholes Filled on Block"].count()
phc = phc.reset_index()
phc.columns=['Ward','Pothole Count']
phc.head()
# Out:
#    Ward  Pothole Count
# 0   1.0            706
# 1   2.0            865
# 2   3.0            628
# 3   4.0            623
# 4   5.0            849

# %%
# read the shapefile as a GeoDataFrame
sf = gpd.GeoDataFrame.from_file("Downloads/497_Data/Wards/chiwards.shp")
sf['Ward'] = sf['ward'].astype(int)
response_map = pd.merge(sf,phc,on='Ward')
ax = response_map.plot(column='Pothole Count', scheme='quantiles', k=5, cmap='RdPu', legend=True, figsize=(10,20))
ax.set_title('Count of Potholes Filled by Ward (2017)', fontsize = 14, fontweight = 'bold')
plt.show()

# %%
wardpop = pd.read_csv("Downloads/497_Data/est_ward_pop.csv", skiprows = 1, skipfooter=1, thousands=',', engine='python')
cols = [0,9,10,11,12,13,14]
wardpop = wardpop[wardpop.columns[cols]]
wardpop.apply(pd.to_numeric)
wardpop.head()
# Out:
#    Ward  Total2016  White2016  Black2016  Asian2016  Latino2016  Other2016
# 0     1      56661      28550       3341       2091       21339       1341
# 1     2      57705      43108       3384       4002        5866       1345
# 2     3      55763      12602      33351       6234        2270       1308
# 3     4      57301      13849      34362       5233        2222       1635
# 4     5      52073      12333      32141       3870        2374       1354

# %%
pop_adj = pd.merge(phc, wardpop, right_on='Ward', left_on='Ward')
pop_adj['New'] = (pop_adj['Pothole Count'] / pop_adj['Total2016']) * 100
pop_adj.head()
# Out:
#    Ward  Pothole Count  Total2016  White2016  Black2016  Asian2016  \
# 0   1.0            706      56661      28550       3341       2091
# 1   2.0            865      57705      43108       3384       4002
# 2   3.0            628      55763      12602      33351       6234
# 3   4.0            623      57301      13849      34362       5233
# 4   5.0            849      52073      12333      32141       3870
#
#    Latino2016  Other2016       New
# 0       21339       1341  1.246007
# 1        5866       1345  1.499004
# 2        2270       1308  1.126195
# 3        2222       1635  1.087241
# 4        2374       1354  1.630403

# %%
df_traffic = pd.read_csv("Downloads/497_Data/avgtraffic.csv")
df_traffic.head()
# Out:
#    ID  Traffic Volume Count Location  Address       Street Date of Count  \
# 0    2                              1708 West  71st Street    03/09/2006
# 1    3                              1275 West  71st Street    02/28/2006
# 2    5                               920 West  71st Street    02/28/2006
# 3    6                               758 West  71st Street    02/28/2006
# 4    7                               240 East      71st St    02/28/2006
#
#    Total Passing Vehicle Volume Vehicle Volume By Each Direction of Traffic  \
# 0                         14600         East Bound: 6900 / West Bound: 7700
# 1                         16500         East Bound: 7800 / West Bound: 8700
# 2                         18200         East Bound: 8800 / West Bound: 9400
# 3                         21600       East Bound: 10400 / West Bound: 11200
# 4                         18300         East Bound: 9000 / West Bound: 9300
#
#     Latitude  Longitude                 Location
# 0  41.764877 -87.666635  (41.764877, -87.666635)
# 1  41.765008 -87.657067  (41.765008, -87.657067)
# 2  41.765153 -87.647751  (41.765153, -87.647751)
# 3  41.765204 -87.644371  (41.765204, -87.644371)
# 4  41.765644 -87.618476  (41.765644, -87.618476)

# %%
from shapely.geometry import Point, Polygon
geometry = [Point(xy) for xy in zip(df_traffic["Longitude"], df_traffic["Latitude"])]
geo_df = gpd.GeoDataFrame(df_traffic, geometry=geometry)
geo_df.head()
# Out:
#    ID  Traffic Volume Count Location  Address       Street Date of Count  \
# 0    2                              1708 West  71st Street    03/09/2006
# 1    3                              1275 West  71st Street    02/28/2006
# 2    5                               920 West  71st Street    02/28/2006
# 3    6                               758 West  71st Street    02/28/2006
# 4    7                               240 East      71st St    02/28/2006
#
#    Total Passing Vehicle Volume Vehicle Volume By Each Direction of Traffic  \
# 0                         14600         East Bound: 6900 / West Bound: 7700
# 1                         16500         East Bound: 7800 / West Bound: 8700
# 2                         18200         East Bound: 8800 / West Bound: 9400
# 3                         21600       East Bound: 10400 / West Bound: 11200
# 4                         18300         East Bound: 9000 / West Bound: 9300
#
#     Latitude  Longitude                 Location  \
# 0  41.764877 -87.666635  (41.764877, -87.666635)
# 1  41.765008 -87.657067  (41.765008, -87.657067)
# 2  41.765153 -87.647751  (41.765153, -87.647751)
# 3  41.765204 -87.644371  (41.765204, -87.644371)
# 4  41.765644 -87.618476  (41.765644, -87.618476)
#
#                                geometry
# 0          POINT (-87.666635 41.764877)
# 1          POINT (-87.657067 41.765008)
# 2  POINT (-87.647751 41.76515300000001)
# 3  POINT (-87.64437099999999 41.765204)
# 4          POINT (-87.618476 41.765644)

# %%
geo_df.crs = sf.crs
zips = gpd.sjoin(sf, geo_df, op='contains')
zips['Date of Count'] = pd.to_datetime(zips['Date of Count'])
zips['Date of Count'].dt.year
zips.head(3)
# Out:
#      shape_area    shape_leng ward  \
# 0  1.160965e+08  93073.340838   12
# 0  1.160965e+08  93073.340838   12
# 0  1.160965e+08  93073.340838   12
#
#                                             geometry  Ward  index_right   ID   \
# 0  POLYGON ((-87.69623470134458 41.85755495238389...    12         1079  1166
# 0  POLYGON ((-87.69623470134458 41.85755495238389...    12          397   431
# 0  POLYGON ((-87.69623470134458 41.85755495238389...    12          571   614
#
#   Traffic Volume Count Location  Address          Street Date of Count  \
# 0                              2550 West         31st St    2006-10-11
# 0                              2703 West       Cermak Rd    2006-09-14
# 0                             2149 South  California Ave    2006-08-15
#
#    Total Passing Vehicle Volume Vehicle Volume By Each Direction of Traffic  \
# 0                         14900         East Bound: 7000 / West Bound: 7900
# 0                         14200         East Bound: 7600 / West Bound: 6600
# 0                         17700       North Bound: 8800 / South Bound: 8900
#
#     Latitude  Longitude                 Location
# 0  41.838156 -87.689438  (41.838156, -87.689438)
# 0  41.851933 -87.693114  (41.851933, -87.693114)
# 0  41.852259 -87.695456  (41.852259, -87.695456)

# %%
zips = zips.groupby(['Ward']).agg({
    'Total Passing Vehicle Volume': 'mean',
})

# %%
pop_adj = pd.merge(phc, zips, right_on='Ward', left_on='Ward')
pop_adj['New'] = (pop_adj['Pothole Count'] / pop_adj['Total Passing Vehicle Volume']) 
pop_adj.head(10)
response_map2 = pd.merge(sf,pop_adj,on='Ward')
ax2 = response_map2.plot(column='New', scheme='quantiles', k=5, cmap='RdPu', legend=True, figsize=(10,20))
ax2.set_title('Count by Ward Adj by Traffic', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# The obvious trend for pothole formation would be seasonality. More potholes will be formed at the end of winter and spring, due to weather and thawing. I would like to confirm this basic trend with the data, so I set a mask of exactly a year from December 2017 to December 2018, assign a month column and plot service request count based on month.

# %% [markdown]
# I group my data by (the beginning of the) month, summing up the number of potholes filled on the block.

# %%
df_month = df[['Creation Date', 'Number of Potholes Filled on Block']].copy()
df_month = df_month.groupby(pd.Grouper(key='Creation Date', freq='1MS')).sum()
df_month = df_month.reset_index()

# %%
mask = (df_month['Creation Date'] > '2017-12-01') & (df_month['Creation Date'] < '2018-12-01')
df_2017 = df_month.loc[mask]
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

locator = mdates.MonthLocator()  # every month
fmt = mdates.DateFormatter('%b')
ax = df_2017.plot.bar(x='Creation Date', y='Number of Potholes Filled on Block')
ax.set_xticklabels(df_2017['Creation Date'].dt.strftime('%b'))
plt.xticks(rotation=0)
ax.set_title("Num Potholes Filled, Dec 1 2017 - Dec 1 2018")
plt.show()

# %% [markdown]
# Next I want to examine the relationship between snowfall and pothole formation (as done in the NYC Pothole Analysis). So I load in my snowfall data - since NOAA was only returning me empty sets when requesting snowfall data, I compiled this data myself from the weather.gov Chicago monthly snowfall records for December, January and February (https://www.weather.gov/lot/Chicago_Dec_Snow_Rankings) The reported 1.4 inches for 2018 December, since it was not on the website, comes from (https://wgntv.com/2019/02/13/was-december-2018-a-record-low-for-snow-in-chicago/)

# %%
dfs = pd.read_csv("Downloads/497_Data/snowfall_ohare.csv")
dfs['DATE'] = pd.to_datetime(dfs['DATE'])
dfs = dfs.groupby(pd.Grouper(key='DATE', freq='1MS')).agg({'SNOW': 'sum'})
dfs = dfs.reset_index()
dfs.head()
# Out:
#         DATE  SNOW
# 0 2010-01-01   9.1
# 1 2010-02-01  22.5
# 2 2010-03-01   1.8
# 3 2010-04-01   0.0
# 4 2010-05-01   0.0

# %% [markdown]
# Next I do an inner join on the months-potholes filled and snowfall data.

# %%
df_sp = pd.concat([dfs.set_index('DATE'),dfp.set_index('Creation Date')], axis=1, join='inner')
df_sp = df_sp.reset_index()
df_sp.head()
# Out:
#        index  SNOW  Number of Potholes Filled on Block
# 0 2010-01-01   9.1                                 0.0
# 1 2010-02-01  22.5                                 0.0
# 2 2010-03-01   1.8                                25.0
# 3 2010-04-01   0.0                                 7.0
# 4 2010-05-01   0.0                                26.0

# %%
winter_mask = (df_sp['index'].map(lambda x: x.month) > 11) | (df_sp['index'].map(lambda x: x.month) < 3)
df_sp = df_sp[winter_mask]
df_sp.tail()
# Out:
#          index  SNOW  Number of Potholes Filled on Block
# 85  2017-02-01   0.0                             60265.0
# 95  2017-12-01   5.3                             15876.0
# 96  2018-01-01   4.6                             40114.0
# 97  2018-02-01  20.3                             97632.0
# 107 2018-12-01   1.4                              3131.0

# %% [markdown]
# Scatterplot and regression line on snowfall vs. number of potholes filled on block, with an r<sup>2</sup> of .22. For comparison, the r<sup>2</sup> found in the NYC Pothole analysis for inches of snowfall was .31

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(df_sp['SNOW'],df_sp['Number of Potholes Filled on Block'])
ax = sns.regplot(x="SNOW", y="Number of Potholes Filled on Block", data=df_sp, color='b', line_kws={'label':"r^2={0:.2f}".format(r_value**2)})
ax.legend()
plt.show()

# %% [markdown]
# I needed to separate the Street Address field (which was all together, as in 1642 W 99TH ST) into Street Number, Direction, Name and Suffix. After having trouble getting the regexes to work, I came up with a somewhat hacky solution to do the splitting. I also want to standardize the street number to eventually join it with my street resurfacing data. Because the 311 data has # of potholes filled on block, +-100 in street address represents 1 block, I round down to the nearest 100 to get the pothole location by block.

# %%
df_potholes = df.copy()
df_potholes['Street Number'] = df_potholes['Street Address'].str.split(' ').str[0]
df_potholes['Street Direction'] = df_potholes['Street Address'].str.split(' ').str[1]
df_potholes['Street Name'] = (df_potholes['Street Address'].str.split(' ').str[2:-1]).str.join(' ')
df_potholes['Street Suffix'] = df_potholes['Street Address'].str.split(' ').str[-1]
df_potholes['Adj Street Number'] = (((df_potholes['Street Number']).astype(int))//100)*100
df_potholes = df_potholes.drop(['Completion Date', 'Type of Service Request', 'Current Activity', 'Most Recent Action', 'Street Address'], axis=1)
df_potholes
# Out:
#        Creation Date     Status Service Request Number  \
# 0         2011-01-01  Completed            11-00002021
# 1         2011-01-01  Completed            11-00002273
# 2         2011-01-01  Completed            11-00002650
# 3         2011-01-01  Completed            11-00002654
# 4         2011-01-01  Completed            11-00002656
# 5         2011-01-01  Completed            11-00002913
# 6         2011-01-01  Completed            11-00002927
# 7         2011-01-01  Completed            11-00003121
# 8         2011-01-01  Completed            11-00003356
# 9         2011-01-01  Completed            11-00003428
# 10        2011-01-01  Completed            11-00001252
# 11        2011-01-01  Completed            11-00001597
# 12        2011-01-01  Completed            11-00001728
# 13        2011-01-01  Completed            11-00002193
# 14        2011-01-01  Completed            11-00002392
# 15        2011-01-01  Completed            11-00002825
# 16        2011-01-01  Completed            11-00002863
# 17        2011-01-01  Completed            11-00003132
# 18        2011-01-01  Completed            11-00003153
# 19        2011-01-01  Completed            11-00001242
# 20        2011-01-01  Completed            11-00001445
# 21        2011-01-01  Completed            11-00002285
# 22        2011-01-01  Completed            11-00002353
# 23        2011-01-01  Completed            11-00002355
# 24        2011-01-01  Completed            11-00003109
# 25        2011-01-01  Completed            11-00003242
# 26        2011-01-01  Completed            11-00003303
# 27        2011-01-01  Completed            11-00001463
# 28        2011-01-01  Completed            11-00001719
# 29        2011-01-01  Completed            11-00001726
# ...              ...        ...                    ...
# 395758    2018-05-23       Open            18-01600683
# 395759    2018-05-23       Open            18-01602793
# 395760    2018-05-23       Open            18-01605003
# 395761    2018-05-24       Open            18-01611189
# 395762    2018-05-24       Open            18-01615061
# 395763    2018-05-24       Open            18-01617078
# 395764    2018-05-24       Open            18-01617816
# 395765    2018-05-24       Open            18-01619638
# 395766    2018-04-19       Open            18-01263960
# 395767    2018-04-20       Open            18-01271697
# 395768    2018-04-22       Open            18-01288231
# 395769    2018-05-02       Open            18-01388924
# 395770    2018-05-02       Open            18-01388977
# 395771    2018-05-02       Open            18-01392282
# 395772    2018-05-03       Open            18-01397967
# 395773    2018-05-03       Open            18-01398447
# 395774    2018-05-03       Open            18-01404696
# 395775    2018-05-03       Open            18-01404849
# 395776    2018-05-04       Open            18-01419929
# 395777    2018-05-06       Open            18-01425867
# 395778    2018-05-06       Open            18-01427380
# 395779    2018-05-07       Open            18-01438889
# 395780    2018-05-07       Open            18-01441434
# 395781    2018-05-07       Open            18-01441540
# 395782    2018-05-07       Open            18-01441544
# 395783    2018-05-07       Open            18-01441596
# 395784    2018-05-07       Open            18-01441907
# 395785    2018-03-17       Open            18-00954950
# 395786    2018-03-08       Open            18-00872304
# 395787    2018-03-11       Open            18-00891202
#
#         Number of Potholes Filled on Block      Zip  X Coordinate  \
# 0                                      5.0  60643.0  1.166945e+06
# 1                                      7.0  60623.0  1.150258e+06
# 2                                      5.0  60619.0  1.180265e+06
# 3                                      3.0  60619.0  1.177809e+06
# 4                                      4.0  60619.0  1.179971e+06
# 5                                     10.0  60621.0  1.177098e+06
# 6                                     12.0  60619.0  1.177592e+06
# 7                                      2.0  60611.0  1.179260e+06
# 8                                     32.0  60643.0  1.166627e+06
# 9                                      2.0  60621.0  1.177080e+06
# 10                                    10.0  60621.0  1.175146e+06
# 11                                     6.0  60641.0  1.140086e+06
# 12                                     0.0  60647.0  1.161200e+06
# 13                                     0.0  60657.0  1.169173e+06
# 14                                     0.0  60617.0  1.192442e+06
# 15                                     1.0  60646.0  1.138714e+06
# 16                                     0.0  60657.0  1.169137e+06
# 17                                     1.0  60646.0  1.138277e+06
# 18                                     1.0  60657.0  1.169047e+06
# 19                                     0.0  60621.0  1.170672e+06
# 20                                     5.0  60617.0  1.193635e+06
# 21                                    29.0  60649.0  1.188854e+06
# 22                                     4.0  60631.0  1.126360e+06
# 23                                     1.0  60631.0  1.126633e+06
# 24                                    14.0  60656.0  1.128945e+06
# 25                                     2.0  60653.0  1.178391e+06
# 26                                     0.0  60616.0  1.176635e+06
# 27                                     1.0  60647.0  1.155522e+06
# 28                                     4.0  60630.0  1.138142e+06
# 29                                     3.0  60630.0  1.138802e+06
# ...                                    ...      ...           ...
# 395758                                 NaN  60629.0  1.154699e+06
# 395759                                 NaN  60629.0  1.155728e+06
# 395760                                 NaN  60639.0  1.134392e+06
# 395761                                 NaN  60622.0  1.156165e+06
# 395762                                 NaN  60646.0  1.138792e+06
# 395763                                 NaN  60629.0  1.152166e+06
# 395764                                 NaN  60608.0  1.170166e+06
# 395765                                 NaN  60641.0  1.148578e+06
# 395766                                 NaN  60618.0  1.149731e+06
# 395767                                 NaN      NaN           NaN
# 395768                                 NaN  60641.0  1.140391e+06
# 395769                                 NaN  60612.0  1.162706e+06
# 395770                                 NaN  60618.0  1.150781e+06
# 395771                                 NaN  60634.0  1.129575e+06
# 395772                                 NaN  60641.0  1.149144e+06
# 395773                                 NaN  60641.0  1.148108e+06
# 395774                                 NaN  60647.0  1.149993e+06
# 395775                                 NaN  60634.0  1.129900e+06
# 395776                                 NaN      NaN           NaN
# 395777                                 0.0  60618.0  1.150543e+06
# 395778                                 NaN  60639.0  1.146593e+06
# 395779                                 NaN  60639.0  1.147409e+06
# 395780                                 NaN  60639.0  1.138564e+06
# 395781                                 NaN  60639.0  1.138892e+06
# 395782                                 NaN  60639.0  1.138546e+06
# 395783                                 NaN  60622.0  1.160173e+06
# 395784                                 NaN  60641.0  1.147791e+06
# 395785                                 0.0  60634.0  1.130516e+06
# 395786                                 NaN  60652.0  1.156427e+06
# 395787                                 NaN      NaN           NaN
#
#         Y Coordinate  Ward  Police District  Community Area   SSA   Latitude  \
# 0       1.839061e+06  19.0             22.0            72.0   NaN  41.714035
# 1       1.881340e+06  22.0             10.0            30.0   NaN  41.830224
# 2       1.853038e+06   6.0              6.0            69.0  51.0  41.751434
# 3       1.852641e+06   6.0              6.0            44.0   NaN  41.750865
# 4       1.852707e+06   6.0              6.0            44.0  51.0  41.750992
# 5       1.856520e+06   6.0              7.0            69.0   NaN  41.761416
# 6       1.854633e+06   6.0              6.0            69.0   NaN  41.756400
# 7       1.905811e+06  42.0             18.0             8.0   NaN  41.896828
# 8       1.839052e+06  19.0             22.0            72.0   NaN  41.714022
# 9       1.857263e+06   6.0              7.0            69.0   NaN  41.763574
# 10      1.863177e+06  20.0              7.0            68.0   NaN  41.779883
# 11      1.926079e+06  38.0             16.0            15.0   NaN  41.953146
# 12      1.915917e+06   1.0             14.0            22.0   NaN  41.925072
# 13      1.922759e+06  44.0             19.0             6.0  17.0  41.943561
# 14      1.839757e+06   7.0              4.0            51.0   NaN  41.715378
# 15      1.944185e+06  41.0             16.0            12.0   NaN  42.003046
# 16      1.922826e+06  44.0             19.0             6.0  17.0  41.943821
# 17      1.942116e+06  41.0             16.0            12.0   NaN  41.997231
# 18      1.921426e+06  44.0             19.0             6.0  17.0  41.940020
# 19      1.863044e+06  16.0              7.0            68.0   NaN  41.779565
# 20      1.849664e+06   8.0              4.0            46.0   NaN  41.742215
# 21      1.854924e+06   8.0              4.0            43.0   NaN  41.756881
# 22      1.937717e+06  41.0             16.0            10.0   NaN  41.985549
# 23      1.937329e+06  41.0             16.0            10.0   NaN  41.984562
# 24      1.935962e+06  41.0             16.0            10.0   NaN  41.980897
# 25      1.873908e+06   3.0              2.0            38.0  56.0  41.809422
# 26      1.890706e+06   3.0              1.0            33.0   NaN  41.855336
# 27      1.918458e+06  35.0             14.0            21.0   NaN  41.932158
# 28      1.931126e+06  45.0             16.0            15.0   NaN  41.967445
# 29      1.931370e+06  45.0             16.0            11.0   NaN  41.967916
# ...              ...   ...              ...             ...   ...        ...
# 395758  1.861638e+06  23.0              8.0            66.0   NaN  41.776029
# 395759  1.865319e+06  23.0              8.0            66.0  59.0  41.786131
# 395760  1.910246e+06  29.0             25.0            25.0   NaN  41.910399
# 395761  1.907832e+06  26.0             14.0            24.0   NaN  41.902989
# 395762  1.938332e+06  39.0             16.0            11.0   NaN  41.987046
# 395763  1.860903e+06  23.0              8.0            65.0   NaN  41.774288
# 395764  1.892459e+06  11.0             12.0            28.0   NaN  41.860433
# 395765  1.926273e+06  39.0             17.0            16.0   NaN  41.953720
# 395766  1.924444e+06  30.0             17.0            16.0   NaN  41.949167
# 395767           NaN   NaN              NaN             NaN   NaN  41.745032
# 395768  1.923424e+06  30.0             16.0            15.0   NaN  41.946457
# 395769  1.904339e+06  26.0             12.0            24.0  29.0  41.893042
# 395770  1.922715e+06  30.0             17.0            21.0   NaN  41.944433
# 395771  1.918880e+06  36.0             25.0            18.0   NaN  41.933882
# 395772  1.921734e+06  30.0             17.0            21.0   NaN  41.941241
# 395773  1.922280e+06  30.0             17.0            16.0   NaN  41.942794
# 395774  1.915281e+06  35.0             25.0            22.0   NaN  41.923914
# 395775  1.919200e+06  36.0             25.0            18.0   NaN  41.934692
# 395776           NaN   NaN              NaN             NaN   NaN  41.855101
# 395777  1.927651e+06  35.0             17.0            16.0   NaN  41.957479
# 395778  1.917206e+06  31.0             25.0            20.0   NaN  41.928525
# 395779  1.912626e+06  35.0             25.0            20.0   NaN  41.916804
# 395780  1.917865e+06  30.0             25.0            19.0   NaN  41.931235
# 395781  1.918066e+06  30.0             25.0            19.0   NaN  41.931185
# 395782  1.918057e+06  30.0             25.0            19.0   NaN  41.931167
# 395783  1.908577e+06  26.0             14.0            24.0   NaN  41.904931
# 395784  1.922822e+06  30.0             17.0            16.0   NaN  41.944274
# 395785  1.920842e+06  36.0             16.0            17.0   NaN  41.939610
# 395786  1.851709e+06  18.0              8.0            70.0   NaN  41.748342
# 395787           NaN   NaN              NaN             NaN   NaN  41.673339
#
#         Longitude                                  Location Street Number  \
# 0      -87.665096   (41.71403466751051, -87.66509581640723)          1642
# 1      -87.724352   (41.830223541014355, -87.7243519544564)          3500
# 2      -87.614820   (41.75143385051753, -87.61481960290558)          7851
# 3      -87.623890   (41.75086472111055, -87.62388985583482)            15
# 4      -87.615824   (41.75099208108744, -87.61582439398472)           359
# 5      -87.626626   (41.76141604711078, -87.62662592657588)          7312
# 6      -87.624870  (41.756400406672974, -87.62486968589552)          7600
# 7      -87.617208   (41.89682804500879, -87.61720770331104)           800
# 8      -87.665222   (41.71402220124287, -87.66522178348544)          9899
# 9      -87.626669   (41.76357428849735, -87.62666940365537)          7200
# 10     -87.633578   (41.77988333178923, -87.63357848131203)          6300
# 11     -87.760956    (41.95314559199465, -87.7609563298001)          5333
# 12     -87.683130   (41.92507240878576, -87.68313006191111)          2152
# 13     -87.653764   (41.94356094269125, -87.65376364321489)          3400
# 14     -87.570907   (41.71537830250349, -87.57090702576498)          2200
# 15     -87.764913  (42.003046021589796, -87.76491345116376)          6731
# 16     -87.653963  (41.943820984368344, -87.65396258925858)          3408
# 17     -87.766818  (41.997231488191716, -87.76681825585933)          6400
# 18     -87.654172  (41.940020360226804, -87.65417210636889)          1000
# 19     -87.649887   (41.77956540902178, -87.64988723339546)          1005
# 20     -87.566238   (41.742214696576944, -87.5662376603757)          8412
# 21     -87.583587  (41.756880566457546, -87.58358699031866)          7600
# 22     -87.810499  (41.985549213927406, -87.81049893731586)          5805
# 23     -87.809800   (41.98456201435575, -87.80980049807322)          5720
# 24     -87.801304  (41.980896905846514, -87.80130393358452)          5476
# 25     -87.621134   (41.80942185653226, -87.62113407842487)           200
# 26     -87.627220   (41.855335797878894, -87.6272199799168)             1
# 27     -87.704132   (41.93215761815935, -87.70413181433115)          3038
# 28     -87.767320  (41.967445382174155, -87.76731998943922)          4751
# 29     -87.765080   (41.96791605355328, -87.76508034348919)          5500
# ...           ...                                       ...           ...
# 395758 -87.708791   (41.77602940509945, -87.70879065354893)          3421
# 395759 -87.704708   (41.78613104128432, -87.70470834759186)          5900
# 395760 -87.781900   (41.91039914975658, -87.78190032273302)          1640
# 395761 -87.701845   (41.90298945801251, -87.70184487243971)          3000
# 395762 -87.764793   (41.98704584156777, -87.76479313500951)          5839
# 395763 -87.717867   (41.77428807547795, -87.71786674408446)          3800
# 395764 -87.650694   (41.86043264374819, -87.65069426696961)          1545
# 395765 -87.729364    (41.9537196963617, -87.72936414926117)          4000
# 395766 -87.724892   (41.94916749336987, -87.72489185687732)          3729
# 395767 -87.624952   (41.74503171565735, -87.62495191048981)          8212
# 395768 -87.759540   (41.94645698332072, -87.75953963493717)          3614
# 395769 -87.678464   (41.893042231131325, -87.6784636140287)          2037
# 395770 -87.721075    (41.94443328298111, -87.7210751190593)          3455
# 395771 -87.799389   (41.93388231150274, -87.79938936606514)          2942
# 395772 -87.727133  (41.941240613904604, -87.72713349972153)          3309
# 395773 -87.731097  (41.942794399523656, -87.73109673739059)          4130
# 395774 -87.724160     (41.923914351423, -87.72416041854434)          2341
# 395775 -87.798187  (41.934692204359045, -87.79818748892369)          3004
# 395776 -87.645121   (41.855100651609604, -87.6451212992546)          2025
# 395777 -87.722445   (41.95747865673265, -87.72244479082352)          3750
# 395778 -87.736584  (41.928524721214714, -87.73658423961467)          2615
# 395779 -87.734016   (41.91680434380327, -87.73401590982121)          1952
# 395780 -87.766098  (41.931234552822154, -87.76609782463002)          2759
# 395781 -87.764954     (41.931185239669, -87.76495446439475)          5529
# 395782 -87.766304  (41.931166501929766, -87.76630374905675)          5601
# 395783 -87.687225    (41.9049312500461, -87.68722509455861)          1300
# 395784 -87.732114   (41.94427360792126, -87.73211377920502)          3501
# 395785 -87.795606   (41.93960978326073, -87.79560565837176)          3249
# 395786 -87.702501   (41.74834169544645, -87.70250100354275)          7946
# 395787 -87.599958    (41.6733393138054, -87.59995842405219)         12134
#
#        Street Direction               Street Name Street Suffix  \
# 0                     W                      99TH            ST
# 1                     S                   PULASKI            RD
# 2                     S  DR MARTIN LUTHER KING JR            DR
# 3                     E                      79TH            ST
# 4                     E                      79TH            ST
# 5                     S                 LAFAYETTE           AVE
# 6                     S                     STATE            ST
# 7                     N                LAKE SHORE            DR
# 8                     S                VANDERPOEL           AVE
# 9                     S                 LAFAYETTE           AVE
# 10                    S                   HARVARD           AVE
# 11                    W               IRVING PARK            RD
# 12                    W                 FULLERTON           AVE
# 13                    N                     CLARK            ST
# 14                    E                      99TH            ST
# 15                    N                     IONIA           AVE
# 16                    N                     CLARK            ST
# 17                    N                  CALDWELL           AVE
# 18                    W                   BELMONT           AVE
# 19                    W                      63RD            ST
# 20                    S                     YATES          BLVD
# 21                    S                  EAST END           AVE
# 22                    N                     ODELL           AVE
# 23                    N                   OCTAVIA           AVE
# 24                    N                     SAYRE           AVE
# 25                    E                      47TH            ST
# 26                    W                 CULLERTON            ST
# 27                    W                  DIVERSEY           AVE
# 28                    N                   CENTRAL           AVE
# 29                    W                  LAWRENCE           AVE
# ...                 ...                       ...           ...
# 395758                W                      64TH            PL
# 395759                S                    SAWYER           AVE
# 395760                N                  MERRIMAC           AVE
# 395761                W                  DIVISION            ST
# 395762                N                    LINDER           AVE
# 395763                W                      65TH            PL
# 395764                S                    MORGAN            ST
# 395765                N                  KEYSTONE           AVE
# 395766                N               SPRINGFIELD           AVE
# 395767                S             DAN RYAN EXPY            IB
# 395768                N                  LOCKWOOD           AVE
# 395769                W                      ERIE            ST
# 395770                N                  RIDGEWAY           AVE
# 395771                N                   NEWLAND           AVE
# 395772                N                 MILWAUKEE           AVE
# 395773                W                    ROSCOE            ST
# 395774                N               SPRINGFIELD           AVE
# 395775                N               NEW ENGLAND           AVE
# 395776                S     DAN RYAN CANALPORT AV            ER
# 395777                W                   BERTEAU           AVE
# 395778                N                   KOSTNER           AVE
# 395779                N                   KILDARE           AVE
# 395780                N                   CENTRAL           AVE
# 395781                W                  DIVERSEY           AVE
# 395782                W                  DIVERSEY           AVE
# 395783                N                   WESTERN           AVE
# 395784                N                 MILWAUKEE           AVE
# 395785                N                  OAK PARK           AVE
# 395786                S                    KEDZIE           AVE
# 395787                S                  DOTY AVE          EAST
#
#         Adj Street Number
# 0                    1600
# 1                    3500
# 2                    7800
# 3                       0
# 4                     300
# 5                    7300
# 6                    7600
# 7                     800
# 8                    9800
# 9                    7200
# 10                   6300
# 11                   5300
# 12                   2100
# 13                   3400
# 14                   2200
# 15                   6700
# 16                   3400
# 17                   6400
# 18                   1000
# 19                   1000
# 20                   8400
# 21                   7600
# 22                   5800
# 23                   5700
# 24                   5400
# 25                    200
# 26                      0
# 27                   3000
# 28                   4700
# 29                   5500
# ...                   ...
# 395758               3400
# 395759               5900
# 395760               1600
# 395761               3000
# 395762               5800
# 395763               3800
# 395764               1500
# 395765               4000
# 395766               3700
# 395767               8200
# 395768               3600
# 395769               2000
# 395770               3400
# 395771               2900
# 395772               3300
# 395773               4100
# 395774               2300
# 395775               3000
# 395776               2000
# 395777               3700
# 395778               2600
# 395779               1900
# 395780               2700
# 395781               5500
# 395782               5600
# 395783               1300
# 395784               3500
# 395785               3200
# 395786               7900
# 395787              12100
#
# [395788 rows x 19 columns]

# %% [markdown]
# Next, I summed up the number of potholes filled on block per adjusted street number. For visualization purposes, since geocoding each new address would be expensive, I took the first latitude/longitude from the sorted dataframe of real addresses before grouping to correspond to our adjusted addresses.

# %%
df4 = (df_potholes.loc[df_potholes['Ward']==19.0]).copy()
df4 = df4.sort_values(['Street Number', 'Street Name', 'Street Direction'])
df4 = df4.groupby(['Adj Street Number', 'Street Direction', 'Street Name', 'Street Suffix']).agg({
    'Location': 'first',
    'Number of Potholes Filled on Block': 'sum'
})
df4 = df4.reset_index()
df4.head()
# Out:
#    Adj Street Number Street Direction Street Name Street Suffix  \
# 0               1400                W       103RD            ST
# 1               1400                W       104TH            ST
# 2               1400                W       105TH            PL
# 3               1400                W       105TH            ST
# 4               1400                W       107TH            ST
#
#                                   Location  Number of Potholes Filled on Block
# 0  (41.70685308300817, -87.65887406317246)                                20.0
# 1  (41.70483067408288, -87.65804188583073)                               153.0
# 2  (41.70233848003942, -87.65782062916087)                                36.0
# 3  (41.70323704708031, -87.65749604582594)                                 0.0
# 4  (41.69931652153758, -87.66011505209809)                                 1.0

# %% [markdown]
# Converted the lat/long string to a tuple, and then to a Point, flipping it into long/lat.

# %%
import ast
df4["Location"] = df4["Location"].apply(lambda x: ast.literal_eval(x))
df4.head()
# Out:
#    Adj Street Number Street Direction Street Name Street Suffix  \
# 0               1400                W       103RD            ST
# 1               1400                W       104TH            ST
# 2               1400                W       105TH            PL
# 3               1400                W       105TH            ST
# 4               1400                W       107TH            ST
#
#                                   Location  Number of Potholes Filled on Block
# 0  (41.70685308300817, -87.65887406317246)                                20.0
# 1  (41.70483067408288, -87.65804188583073)                               153.0
# 2  (41.70233848003942, -87.65782062916087)                                36.0
# 3  (41.70323704708031, -87.65749604582594)                                 0.0
# 4  (41.69931652153758, -87.66011505209809)                                 1.0

# %%
import geopandas as gpd
from shapely.geometry import Point
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None
df4["Location"] = df4.apply(lambda x: Point(x["Location"][1], x["Location"][0]) , axis = 1)
df4.head()
# Out:
#    Adj Street Number Street Direction Street Name Street Suffix  \
# 0               1400                W       103RD            ST
# 1               1400                W       104TH            ST
# 2               1400                W       105TH            PL
# 3               1400                W       105TH            ST
# 4               1400                W       107TH            ST
#
#                                        Location  \
# 0  POINT (-87.65887406317246 41.70685308300817)
# 1  POINT (-87.65804188583073 41.70483067408288)
# 2  POINT (-87.65782062916087 41.70233848003942)
# 3  POINT (-87.65749604582594 41.70323704708031)
# 4  POINT (-87.66011505209809 41.69931652153758)
#
#    Number of Potholes Filled on Block
# 0                                20.0
# 1                               153.0
# 2                                36.0
# 3                                 0.0
# 4                                 1.0

# %% [markdown]
# Scaled the # of potholes filled on block by a percentage of total potholes filled

# %%
tot1 = df4['Number of Potholes Filled on Block'].sum()
df4['Percentage'] = df4['Number of Potholes Filled on Block'].apply(lambda x: (x/tot1)*100)
df4.describe()
# Out:
#        Adj Street Number  Number of Potholes Filled on Block   Percentage
# count        1156.000000                         1156.000000  1156.000000
# mean         7310.467128                          145.879758     0.086505
# std          3950.435709                          176.802642     0.104842
# min          1400.000000                            0.000000     0.000000
# 25%          2600.000000                           21.000000     0.012453
# 50%          9700.000000                           79.000000     0.046846
# 75%         10700.000000                          209.000000     0.123935
# max         11800.000000                         1523.000000     0.903123

# %% [markdown]
# Created a function to a apply a scaling number based on each percentage value - this is for the visualization

# %%
def alert(c):
  if c["Number of Potholes Filled on Block"] <=0.012453:
    return .5
  elif c["Percentage"] >=0.50:
    return 200.0
  elif c["Percentage"] >=0.223935:
    return 50.0
  else:
    return 1
df4['Scale'] = df4.apply(alert, axis=1)
df4.head()
# Out:
#    Adj Street Number Street Direction Street Name Street Suffix  \
# 0               1400                W       103RD            ST
# 1               1400                W       104TH            ST
# 2               1400                W       105TH            PL
# 3               1400                W       105TH            ST
# 4               1400                W       107TH            ST
#
#                                        Location  \
# 0  POINT (-87.65887406317246 41.70685308300817)
# 1  POINT (-87.65804188583073 41.70483067408288)
# 2  POINT (-87.65782062916087 41.70233848003942)
# 3  POINT (-87.65749604582594 41.70323704708031)
# 4  POINT (-87.66011505209809 41.69931652153758)
#
#    Number of Potholes Filled on Block  Percentage  Scale
# 0                                20.0    0.011860    1.0
# 1                               153.0    0.090727    1.0
# 2                                36.0    0.021348    1.0
# 3                                 0.0    0.000000    0.5
# 4                                 1.0    0.000593    1.0

# %%
# These are the "Tableau 20" colors as RGB.  
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.  
for i in range(len(tableau20)):
    r, g, b = tableau20[i]
    tableau20[i] = (r / 255., g / 255., b / 255.)

# %%
plt.style.use('ggplot')
gdf = gpd.GeoDataFrame(df4, geometry='Location')
g1 = gpd.read_file("Downloads/497_Data/Wards/chiwards.shp")
ward_19 = g1[g1['ward'] == '19'] 
ax = ward_19.plot(color='white', edgecolor='black', figsize=(20,10))
ax = gdf.plot(ax=ax, c=[tableau20[6]], alpha=0.75, markersize=df4['Scale'])
plt.xlim([-87.73, -87.65])
plt.ylim([41.67, 41.74])  
plt.show()

# %% [markdown]
# Used this tutorial to generate the map:
# https://automating-gis-processes.github.io/2018/notebooks/L5/interactive-map-folium.html

# %%
import mplleaflet
mplleaflet.show(fig=ax.figure, crs=gdf.crs)

# %% [markdown]
# Next I load in my street moratorium data (which I am using to approximate street resurface dates). I change the start and end dates to pandas datetime

# %%
df_mora = pd.read_csv("Downloads/497_Data/moratoriums.csv")
df_mora = df_mora[df_mora["MORATORIUM TYPE"] == "Street Resurfacing"]
df_mora['START DATE'] = pd.to_datetime(df_mora['START DATE'], format='%m/%d/%Y')
df_mora['EXPIRATION DATE'] = pd.to_datetime(df_mora['EXPIRATION DATE'], format='%m/%d/%Y')

# %% [markdown]
# 86% of the data was 5 year gaps, which makes sense given the CDOT description, but the next highest frequency of (expiration date - start date) (.8%) was 0 year, some rows having only a 10 day gap between start and expiry, which made no sense. Because I had no idea how to interpret that, in the end I weighed that only keeping the 5-year differences data would be better than keeping data I had no idea actually represented resurface date. Also dropped duplicates.

# %%
df_mora['SME'] = df_mora['EXPIRATION DATE'].dt.year - df_mora['START DATE'].dt.year
df_mora = df_mora[df_mora['SME']==5] # SME = start minus expire
df_mora = df_mora.drop_duplicates()

# %% [markdown]
# The median of the resurface range was 95.0 and the mean 141 (difference in street address numbers). I take this to mean that the average resurface range is about a block.

# %%
df_mora.describe()
# Out:
#        STREET ADDRESS BEGIN  STREET ADDRESS END      SME
# count          10618.000000        10618.000000  10618.0
# mean            3936.679224         4077.689019      5.0
# std             2958.794364         2961.904842      0.0
# min                0.000000            4.000000      5.0
# 25%             1600.000000         1702.000000      5.0
# 50%             3301.000000         3459.000000      5.0
# 75%             5800.000000         5960.500000      5.0
# max            13336.000000        13629.000000      5.0

# %% [markdown]
# <b>TODO:</b>
# Number of potholes by length of time since resurfacing OR resurfacing gap

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

g1 = gpd.read_file("Downloads/497_Data/Streets/street_center.shp")
#g1[g1['geometry'].isnull()]
g1 = g1[pd.notnull(g1['geometry'])]
g1.head().T
# Out:
#                                                             0  \
# class                                                       4
# date_creat                                         1999-01-01
# time_creat                                       00:00:00.000
# create_use                                           EXISTING
# dir_travel                                                  F
# edit_date                                                   0
# edit_type                                                None
# ewns                                                     -232
# ewns_coord                                                232
# ewns_dir                                                    W
# f_cross                                  245|W|ENGLEWOOD|AVE|
# f_cross_st                                               2208
# f_zlev                                                      0
# flag_strin                                               None
# fnode_id                                                10809
# l_censusbl                                    170316802002035
# l_f_add                                                     0
# l_fips                                                  14000
# l_parity                                                    O
# l_t_add                                                     0
# l_zip                                                   60621
# length                                                220.566
# logiclf                                                     0
# logiclt                                                     0
# logicrf                                                  6228
# logicrt                                                  6248
# objectid                                                  510
# oneway_dir                                                  S
# pre_dir                                                     S
# r_censusbl                                    170316802002035
# r_f_add                                                  6228
# r_fips                                                  14000
# r_parity                                                    E
# r_t_add                                                  6248
# r_zip                                                   60621
# shape_len                                             220.566
# status                                                      N
# date_statu                                         1999-01-01
# time_statu                                       00:00:00.000
# street_nam                                               YALE
# street_typ                                                AVE
# streetname                                               1782
# suf_dir                                                  None
# t_cross                                             6250|S|||
# t_cross_st                                                  0
# t_zlev                                                      0
# tiered                                                      N
# tnode_id                                                16581
# trans_id                                               127104
# date_updat                                         1999-01-01
# time_updat                                       00:00:00.000
# update_use                                           EXISTING
# geometry    LINESTRING (-87.63187018233509 41.780809747581...
#
#                                                             1  \
# class                                                       2
# date_creat                                         1999-01-01
# time_creat                                       00:00:00.000
# create_use                                           EXISTING
# dir_travel                                                  B
# edit_date                                                   0
# edit_type                                                None
# ewns                                                        0
# ewns_coord                                                  0
# ewns_dir                                                 None
# f_cross                                        800|E|73RD|ST|
# f_cross_st                                                170
# f_zlev                                                      0
# flag_strin                                               None
# fnode_id                                                 6501
# l_censusbl                                    170316908003004
# l_f_add                                                  7301
# l_fips                                                  14000
# l_parity                                                    O
# l_t_add                                                  7359
# l_zip                                                   60619
# length                                                664.775
# logiclf                                                  7301
# logiclt                                                  7399
# logicrf                                                  7300
# logicrt                                                  7398
# objectid                                                  511
# oneway_dir                                               None
# pre_dir                                                     S
# r_censusbl                                    170316909002000
# r_f_add                                                  7300
# r_fips                                                  14000
# r_parity                                                    E
# r_t_add                                                  7358
# r_zip                                                   60619
# shape_len                                             664.775
# status                                                      N
# date_statu                                         1999-01-01
# time_statu                                       00:00:00.000
# street_nam                                      COTTAGE GROVE
# street_typ                                                AVE
# streetname                                               1236
# suf_dir                                                  None
# t_cross                                        800|E|74TH|ST|
# t_cross_st                                                172
# t_zlev                                                      0
# tiered                                                      N
# tnode_id                                                34082
# trans_id                                               128895
# date_updat                                         1999-01-01
# time_updat                                       00:00:00.000
# update_use                                           EXISTING
# geometry    LINESTRING (-87.60548932047928 41.762229643527...
#
#                                                             2  \
# class                                                       4
# date_creat                                         1999-01-01
# time_creat                                       00:00:00.000
# create_use                                           EXISTING
# dir_travel                                                  B
# edit_date                                                   0
# edit_type                                                None
# ewns                                                    -2500
# ewns_coord                                               2500
# ewns_dir                                                    W
# f_cross                                      2500|W|108TH|ST|
# f_cross_st                                               1803
# f_zlev                                                      0
# flag_strin                                               None
# fnode_id                                                15338
# l_censusbl                                    170317503001011
# l_f_add                                                 10801
# l_fips                                                  14000
# l_parity                                                    O
# l_t_add                                                 10859
# l_zip                                                   60655
# length                                                665.378
# logiclf                                                 10801
# logiclt                                                 10899
# logicrf                                                 10800
# logicrt                                                 10898
# objectid                                                  512
# oneway_dir                                               None
# pre_dir                                                     S
# r_censusbl                                    170317503001010
# r_f_add                                                 10800
# r_fips                                                  14000
# r_parity                                                    E
# r_t_add                                                 10858
# r_zip                                                   60655
# shape_len                                             665.378
# status                                                      N
# date_statu                                         1999-01-01
# time_statu                                       00:00:00.000
# street_nam                                           CAMPBELL
# street_typ                                                AVE
# streetname                                               1177
# suf_dir                                                  None
# t_cross                                      2500|W|109TH|ST|
# t_cross_st                                               1805
# t_zlev                                                      0
# tiered                                                      N
# tnode_id                                                22358
# trans_id                                               142645
# date_updat                                         1999-01-01
# time_updat                                       00:00:00.000
# update_use                                           EXISTING
# geometry    LINESTRING (-87.6838184819274 41.6972438444297...
#
#                                                             3  \
# class                                                       4
# date_creat                                         1999-01-01
# time_creat                                       00:00:00.000
# create_use                                           EXISTING
# dir_travel                                                  B
# edit_date                                                   0
# edit_type                                                None
# ewns                                                     -932
# ewns_coord                                                932
# ewns_dir                                                    W
# f_cross                                            11024|S|||
# f_cross_st                                                  0
# f_zlev                                                      0
# flag_strin                                               None
# fnode_id                                                15799
# l_censusbl                                    170317501001011
# l_f_add                                                     0
# l_fips                                                  14000
# l_parity                                                    O
# l_t_add                                                     0
# l_zip                                                   60643
# length                                                152.565
# logiclf                                                     0
# logiclt                                                     0
# logicrf                                                 11026
# logicrt                                                 11032
# objectid                                                  513
# oneway_dir                                               None
# pre_dir                                                     S
# r_censusbl                                    170317501001010
# r_f_add                                                 11026
# r_fips                                                  14000
# r_parity                                                    E
# r_t_add                                                 11032
# r_zip                                                   60643
# shape_len                                             152.565
# status                                                      N
# date_statu                                         1999-01-01
# time_statu                                       00:00:00.000
# street_nam                                           SANGAMON
# street_typ                                                 ST
# streetname                                               1696
# suf_dir                                                  None
# t_cross                                          ||DEAD END||
# t_cross_st                                                  0
# t_zlev                                                      0
# tiered                                                      N
# tnode_id                                                28881
# trans_id                                               148189
# date_updat                                         1999-01-01
# time_updat                                       00:00:00.000
# update_use                                           EXISTING
# geometry    LINESTRING (-87.64584189298007 41.693398400444...
#
#                                                             4
# class                                                       4
# date_creat                                         1999-01-01
# time_creat                                       00:00:00.000
# create_use                                           EXISTING
# dir_travel                                                  B
# edit_date                                                   0
# edit_type                                                None
# ewns                                                   -11800
# ewns_coord                                              11800
# ewns_dir                                                    S
# f_cross                                11800|S|VINCENNES|AVE|
# f_cross_st                                               1752
# f_zlev                                                      0
# flag_strin                                               None
# fnode_id                                                36407
# l_censusbl                                    170317505003010
# l_f_add                                                  1933
# l_fips                                                  14000
# l_parity                                                    O
# l_t_add                                                  1959
# l_zip                                                   60643
# length                                                332.691
# logiclf                                                  1933
# logiclt                                                  1999
# logicrf                                                  1932
# logicrt                                                  1998
# objectid                                                  514
# oneway_dir                                               None
# pre_dir                                                     W
# r_censusbl                                    170317505003011
# r_f_add                                                  1932
# r_fips                                                  14000
# r_parity                                                    E
# r_t_add                                                  1958
# r_zip                                                   60643
# shape_len                                             332.691
# status                                                      N
# date_statu                                         1999-01-01
# time_statu                                       00:00:00.000
# street_nam                                              118TH
# street_typ                                                 ST
# streetname                                               1823
# suf_dir                                                  None
# t_cross                                    11799|S|CHURCH|ST|
# t_cross_st                                               1214
# t_zlev                                                      0
# tiered                                                      N
# tnode_id                                                36534
# trans_id                                               139728
# date_updat                                         1999-01-01
# time_updat                                       00:00:00.000
# update_use                                           EXISTING
# geometry    LINESTRING (-87.67053671319235 41.679759274890...

# %%
g2 = gpd.read_file("Downloads/497_Data/Wards/chiwards.shp")
g2 = g2[pd.notnull(g2['geometry'])]
g2.head()
# Out:
#      shape_area    shape_leng ward  \
# 0  1.160965e+08  93073.340838   12
# 1  1.031436e+08  97901.323833   16
# 2  6.558830e+07  82183.694820   15
# 3  1.372904e+08  90105.195619   20
# 4  4.973346e+07  38122.692826   49
#
#                                             geometry
# 0  POLYGON ((-87.69623470134458 41.85755495238389...
# 1  POLYGON ((-87.66288923669032 41.79883809868242...
# 2  POLYGON ((-87.69817510963803 41.81729440755995...
# 3  POLYGON ((-87.65524133440029 41.80883316182794...
# 4  POLYGON ((-87.66420403810295 42.02126158052747...

# %%
g3 = gpd.sjoin(g1, g2, op='within')

# %%
g4 = g3.loc[g3['ward']=='19']
g4.head().T
# Out:
#                                                            2    \
# class                                                        4
# date_creat                                          1999-01-01
# time_creat                                        00:00:00.000
# create_use                                            EXISTING
# dir_travel                                                   B
# edit_date                                                    0
# edit_type                                                 None
# ewns                                                     -2500
# ewns_coord                                                2500
# ewns_dir                                                     W
# f_cross                                       2500|W|108TH|ST|
# f_cross_st                                                1803
# f_zlev                                                       0
# flag_strin                                                None
# fnode_id                                                 15338
# l_censusbl                                     170317503001011
# l_f_add                                                  10801
# l_fips                                                   14000
# l_parity                                                     O
# l_t_add                                                  10859
# l_zip                                                    60655
# length                                                 665.378
# logiclf                                                  10801
# logiclt                                                  10899
# logicrf                                                  10800
# logicrt                                                  10898
# objectid                                                   512
# oneway_dir                                                None
# pre_dir                                                      S
# r_censusbl                                     170317503001010
# r_f_add                                                  10800
# r_fips                                                   14000
# r_parity                                                     E
# r_t_add                                                  10858
# r_zip                                                    60655
# shape_len                                              665.378
# status                                                       N
# date_statu                                          1999-01-01
# time_statu                                        00:00:00.000
# street_nam                                            CAMPBELL
# street_typ                                                 AVE
# streetname                                                1177
# suf_dir                                                   None
# t_cross                                       2500|W|109TH|ST|
# t_cross_st                                                1805
# t_zlev                                                       0
# tiered                                                       N
# tnode_id                                                 22358
# trans_id                                                142645
# date_updat                                          1999-01-01
# time_updat                                        00:00:00.000
# update_use                                            EXISTING
# geometry     LINESTRING (-87.6838184819274 41.6972438444297...
# index_right                                                 41
# shape_area                                         2.14115e+08
# shape_leng                                              102340
# ward                                                        19
#
#                                                            30   \
# class                                                        2
# date_creat                                          1999-01-01
# time_creat                                        00:00:00.000
# create_use                                            EXISTING
# dir_travel                                                   B
# edit_date                                                    0
# edit_type                                                 None
# ewns                                                    -10300
# ewns_coord                                               10300
# ewns_dir                                                     S
# f_cross                                  10300|S|ARTESIAN|AVE|
# f_cross_st                                                1095
# f_zlev                                                       0
# flag_strin                                                None
# fnode_id                                                 27679
# l_censusbl                                     170317205001001
# l_f_add                                                   2433
# l_fips                                                   14000
# l_parity                                                     O
# l_t_add                                                   2459
# l_zip                                                    60655
# length                                                 333.333
# logiclf                                                   2433
# logiclt                                                   2499
# logicrf                                                   2432
# logicrt                                                   2498
# objectid                                                   555
# oneway_dir                                                None
# pre_dir                                                      W
# r_censusbl                                     170317204001016
# r_f_add                                                   2432
# r_fips                                                   14000
# r_parity                                                     E
# r_t_add                                                   2458
# r_zip                                                    60655
# shape_len                                              333.333
# status                                                       N
# date_statu                                          1999-01-01
# time_statu                                        00:00:00.000
# street_nam                                               103RD
# street_typ                                                  ST
# streetname                                                1793
# suf_dir                                                   None
# t_cross                                  10300|S|CAMPBELL|AVE|
# t_cross_st                                                1177
# t_zlev                                                       0
# tiered                                                       N
# tnode_id                                                 25885
# trans_id                                                142368
# date_updat                                          1999-01-01
# time_updat                                        00:00:00.000
# update_use                                            EXISTING
# geometry     LINESTRING (-87.68289701751343 41.706377963140...
# index_right                                                 41
# shape_area                                         2.14115e+08
# shape_leng                                              102340
# ward                                                        19
#
#                                                            73   \
# class                                                        4
# date_creat                                          1999-01-01
# time_creat                                        00:00:00.000
# create_use                                            EXISTING
# dir_travel                                                   B
# edit_date                                                    0
# edit_type                                                 None
# ewns                                                     -2632
# ewns_coord                                                2632
# ewns_dir                                                     W
# f_cross                                       2629|W|100TH|PL|
# f_cross_st                                                1786
# f_zlev                                                       0
# flag_strin                                                None
# fnode_id                                                 23884
# l_censusbl                                     170317204002009
# l_f_add                                                  10033
# l_fips                                                   14000
# l_parity                                                     O
# l_t_add                                                  10059
# l_zip                                                    60655
# length                                                 330.393
# logiclf                                                  10033
# logiclt                                                  10099
# logicrf                                                  10030
# logicrt                                                  10098
# objectid                                                   583
# oneway_dir                                                None
# pre_dir                                                      S
# r_censusbl                                     170317204002006
# r_f_add                                                  10030
# r_fips                                                   14000
# r_parity                                                     E
# r_t_add                                                  10058
# r_zip                                                    60655
# shape_len                                              330.393
# status                                                       N
# date_statu                                          1999-01-01
# time_statu                                        00:00:00.000
# street_nam                                              TALMAN
# street_typ                                                 AVE
# streetname                                                1733
# suf_dir                                                   None
# t_cross                                       2631|W|101ST|ST|
# t_cross_st                                                1789
# t_zlev                                                       0
# tiered                                                       N
# tnode_id                                                  5223
# trans_id                                                142397
# date_updat                                          1999-01-01
# time_updat                                        00:00:00.000
# update_use                                            EXISTING
# geometry     LINESTRING (-87.6879252195578 41.7108780461457...
# index_right                                                 41
# shape_area                                         2.14115e+08
# shape_leng                                              102340
# ward                                                        19
#
#                                                            74   \
# class                                                        4
# date_creat                                          1999-01-01
# time_creat                                        00:00:00.000
# create_use                                            EXISTING
# dir_travel                                                   B
# edit_date                                                    0
# edit_type                                                 None
# ewns                                                     -3400
# ewns_coord                                                3400
# ewns_dir                                                     W
# f_cross                                       3400|W|111TH|ST|
# f_cross_st                                                1809
# f_zlev                                                       0
# flag_strin                                                None
# fnode_id                                                  6122
# l_censusbl                                     170317404001003
# l_f_add                                                  11101
# l_fips                                                   14000
# l_parity                                                     O
# l_t_add                                                  11165
# l_zip                                                    60655
# length                                                 713.242
# logiclf                                                  11101
# logiclt                                                  11199
# logicrf                                                  11100
# logicrt                                                  11198
# objectid                                                   584
# oneway_dir                                                None
# pre_dir                                                      S
# r_censusbl                                     170317404001004
# r_f_add                                                  11100
# r_fips                                                   14000
# r_parity                                                     E
# r_t_add                                                  11164
# r_zip                                                    60655
# shape_len                                              713.242
# status                                                       N
# date_statu                                          1999-01-01
# time_statu                                        00:00:00.000
# street_nam                                               HOMAN
# street_typ                                                 AVE
# streetname                                                1421
# suf_dir                                                   None
# t_cross                                             11201|S|||
# t_cross_st                                                   0
# t_zlev                                                       0
# tiered                                                       N
# tnode_id                                                 22405
# trans_id                                                142905
# date_updat                                          1999-01-01
# time_updat                                        00:00:00.000
# update_use                                            EXISTING
# geometry     LINESTRING (-87.70573855814474 41.691492810155...
# index_right                                                 41
# shape_area                                         2.14115e+08
# shape_leng                                              102340
# ward                                                        19
#
#                                                            122
# class                                                        3
# date_creat                                          1999-01-01
# time_creat                                        00:00:00.000
# create_use                                            EXISTING
# dir_travel                                                   B
# edit_date                                                    0
# edit_type                                                 None
# ewns                                                    -11500
# ewns_coord                                               11500
# ewns_dir                                                     S
# f_cross                                  11500|S|CAMPBELL|AVE|
# f_cross_st                                                1177
# f_zlev                                                       0
# flag_strin                                                None
# fnode_id                                                 33947
# l_censusbl                                     170317504002002
# l_f_add                                                   2501
# l_fips                                                   14000
# l_parity                                                     O
# l_t_add                                                   2527
# l_zip                                                    60655
# length                                                 336.029
# logiclf                                                   2501
# logiclt                                                   2531
# logicrf                                                   2500
# logicrt                                                   2530
# objectid                                                   631
# oneway_dir                                                None
# pre_dir                                                      W
# r_censusbl                                     170317504001022
# r_f_add                                                   2500
# r_fips                                                   14000
# r_parity                                                     E
# r_t_add                                                   2526
# r_zip                                                    60655
# shape_len                                              336.029
# status                                                       N
# date_statu                                          1999-01-01
# time_statu                                        00:00:00.000
# street_nam                                               115TH
# street_typ                                                  ST
# streetname                                                1817
# suf_dir                                                   None
# t_cross                                 11500|S|MAPLEWOOD|AVE|
# t_cross_st                                                1576
# t_zlev                                                       0
# tiered                                                       N
# tnode_id                                                  4771
# trans_id                                                142807
# date_updat                                          1999-01-01
# time_updat                                        00:00:00.000
# update_use                                            EXISTING
# geometry     LINESTRING (-87.68338170809722 41.684507606823...
# index_right                                                 41
# shape_area                                         2.14115e+08
# shape_leng                                              102340
# ward                                                        19

# %%
ax = g4.plot(color='blue', edgecolor='black', figsize=(20,10))
plt.show()
